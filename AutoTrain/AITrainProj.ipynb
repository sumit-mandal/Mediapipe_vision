# %%
import cv2
import numpy as np
import time
import sys
import math
sys.path.append('D:/ComputerVision_MultipleProj/PoseEstimationProject')

# %%
import PoseModule as pm

# %%
cap = cv2.VideoCapture('AITrainer/curls2.mp4')
count = 0
direction = 0
pTime = 0

detector = pm.poseDetector()
while cap.isOpened():
    success,img = cap.read()
    img = cv2.resize(img,(800,800))
    
    if success == True:
        
        img = detector.findPose(img,False)
        lmList = detector.findPosition(img,False)
#         print(lmList)
        
        if len(lmList)!= 0:
            angle = detector.findAngle(img,11,13,15)
            print(angle)
            per = np.interp(angle, (210, 310), (0, 100))
            bar = np.interp(angle, (220, 310), (650, 100))
            color = (255, 0, 255)
            if per == 100:
                color = (0, 255, 0)
                if direction == 0:
                    count += 0.5
                    direction = 1
            if per == 0:
                color = (0, 255, 0)
                if direction == 1:
                    count += 0.5
                    direction = 0
            print(count)
            # Draw Bar
            cv2.rectangle(img, (1100, 100), (1175, 650), color, 3)
#             cv2.rectangle(img, (1100, int(bar)), (1175, 650), color, cv2.FILLED)
#             cv2.putText(img, f'{int(per)} %', (1100, 75), cv2.FONT_HERSHEY_PLAIN, 4,
#                         color, 4)
            # Draw Curl Count
            cv2.rectangle(img, (0, 450), (250, 720), (0, 255, 0), cv2.FILLED)
            cv2.putText(img, str(int(count)), (45, 670), cv2.FONT_HERSHEY_PLAIN, 15,
                        (255, 0, 0), 25)
        cTime = time.time()
        fps = 1 / (cTime - pTime)
        pTime = cTime
        cv2.putText(img, str(int(fps)), (50, 100), cv2.FONT_HERSHEY_PLAIN, 5,
                    (255, 0, 0), 5)
            

        
        cv2.imshow('image',img)
        if cv2.waitKey(1) == ord('q'):
            break
    else:
        break

cap.release()  
cv2.destroyAllWindows()
# Out:
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0
# None
# 0

# %%
! git add AITrainProj.ipynb
! git commit -m "20:47/02-01-2022"
! git push origin main -f
# Out:
# warning: LF will be replaced by CRLF in AutoTrain/AITrainProj.ipynb.
# The file will have its original line endings in your working directory
# [main d8db10c] 20:47/02-01-2022
#  1 file changed, 362 insertions(+)
#  create mode 100644 AutoTrain/AITrainProj.ipynb
# To https://github.com/sumit-mandal/mediapipe_vision.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/sumit-mandal/mediapipe_vision.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
